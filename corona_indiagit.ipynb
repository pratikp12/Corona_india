# %%
import pandas as pd
import numpy as nm
import matplotlib.pyplot as plt
import seaborn as sns
covid=pd.read_csv("covid_19_india.csv")
covid
# Out:
#        Sno      Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0        1  30/01/20  6:00 PM               Kerala                       1
# 1        2  31/01/20  6:00 PM               Kerala                       1
# 2        3  01/02/20  6:00 PM               Kerala                       2
# 3        4  02/02/20  6:00 PM               Kerala                       3
# 4        5  03/02/20  6:00 PM               Kerala                       3
# ...    ...       ...      ...                  ...                     ...
# 1537  1538  02/05/20  5:00 PM            Telengana                       -
# 1538  1539  02/05/20  5:00 PM              Tripura                       -
# 1539  1540  02/05/20  5:00 PM          Uttarakhand                       -
# 1540  1541  02/05/20  5:00 PM        Uttar Pradesh                       -
# 1541  1542  02/05/20  5:00 PM          West Bengal                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# ...

# %% [markdown]
# # Removing unwanted colums

# %%
covid1=covid.drop(['ConfirmedIndianNational','ConfirmedForeignNational'],axis=1)
covid1
# Out:
#        Sno      Date     Time State/UnionTerritory  Cured  Deaths  Confirmed
# 0        1  30/01/20  6:00 PM               Kerala      0       0          1
# 1        2  31/01/20  6:00 PM               Kerala      0       0          1
# 2        3  01/02/20  6:00 PM               Kerala      0       0          2
# 3        4  02/02/20  6:00 PM               Kerala      0       0          3
# 4        5  03/02/20  6:00 PM               Kerala      0       0          3
# ...    ...       ...      ...                  ...    ...     ...        ...
# 1537  1538  02/05/20  5:00 PM            Telengana    441      26       1039
# 1538  1539  02/05/20  5:00 PM              Tripura      2       0          2
# 1539  1540  02/05/20  5:00 PM          Uttarakhand     36       0         58
# 1540  1541  02/05/20  5:00 PM        Uttar Pradesh    654      42       2328
# 1541  1542  02/05/20  5:00 PM          West Bengal    139      33        795
#
# [1542 rows x 7 columns]

# %% [markdown]
# # selecting rows which show data of date 02/05/20

# %%
covid_latest=covid1[covid1['Date']=='02/05/20']

# %% [markdown]
# # Performing data processing

# %%
#sorting rows based on Confirmed cases statewise
covid_latest.sort_values('Confirmed')
# Out:
#        Sno      Date     Time         State/UnionTerritory  Cured  Deaths  \
# 1512  1513  02/05/20  5:00 PM            Arunachal Pradesh      1       0
# 1531  1532  02/05/20  5:00 PM                      Mizoram      0       0
# 1529  1530  02/05/20  5:00 PM                      Manipur      2       0
# 1538  1539  02/05/20  5:00 PM                      Tripura      2       0
# 1518  1519  02/05/20  5:00 PM                          Goa      7       0
# 1533  1534  02/05/20  5:00 PM                   Puducherry      5       0
# 1530  1531  02/05/20  5:00 PM                    Meghalaya      0       1
# 1526  1527  02/05/20  5:00 PM                       Ladakh     17       0
# 1510  1511  02/05/20  5:00 PM  Andaman and Nicobar Islands     16       0
# 1521  1522  02/05/20  5:00 PM             Himachal Pradesh     30       1
# 1513  1514  02/05/20  5:00 PM                        Assam     32       1
# 1516  1517  02/05/20  5:00 PM                 Chhattisgarh     36       0
# ...

# %%
#sorting rows based on Confirmed cases statewise in descending order date 02/05/20
#showing first 10 rows 
covid_latest.sort_values(by='Confirmed', ascending=False)[:10]
# Out:
#        Sno      Date     Time State/UnionTerritory  Cured  Deaths  Confirmed
# 1528  1529  02/05/20  5:00 PM          Maharashtra   1879     485      11506
# 1519  1520  02/05/20  5:00 PM              Gujarat    735     236       4721
# 1517  1518  02/05/20  5:00 PM                Delhi   1167      61       3738
# 1527  1528  02/05/20  5:00 PM       Madhya Pradesh    524     145       2719
# 1535  1536  02/05/20  5:00 PM            Rajasthan   1116      62       2666
# 1536  1537  02/05/20  5:00 PM           Tamil Nadu   1312      28       2526
# 1540  1541  02/05/20  5:00 PM        Uttar Pradesh    654      42       2328
# 1511  1512  02/05/20  5:00 PM       Andhra Pradesh    403      33       1463
# 1537  1538  02/05/20  5:00 PM            Telengana    441      26       1039
# 1541  1542  02/05/20  5:00 PM          West Bengal    139      33        795

# %%
#sorting rows based on Death statewise in descending order date 02/05/20
#showing first 10 rows
# here you can see Maharashtra state Death number is high
covid_latest.sort_values(by='Deaths', ascending=False)[:10]
# Out:
#        Sno      Date     Time State/UnionTerritory  Cured  Deaths  Confirmed
# 1528  1529  02/05/20  5:00 PM          Maharashtra   1879     485      11506
# 1519  1520  02/05/20  5:00 PM              Gujarat    735     236       4721
# 1527  1528  02/05/20  5:00 PM       Madhya Pradesh    524     145       2719
# 1535  1536  02/05/20  5:00 PM            Rajasthan   1116      62       2666
# 1517  1518  02/05/20  5:00 PM                Delhi   1167      61       3738
# 1540  1541  02/05/20  5:00 PM        Uttar Pradesh    654      42       2328
# 1511  1512  02/05/20  5:00 PM       Andhra Pradesh    403      33       1463
# 1541  1542  02/05/20  5:00 PM          West Bengal    139      33        795
# 1536  1537  02/05/20  5:00 PM           Tamil Nadu   1312      28       2526
# 1537  1538  02/05/20  5:00 PM            Telengana    441      26       1039

# %%
#Bar graph that Top 10 state with Confirmed case 
covid_latest.sort_values(by='Confirmed', ascending=False)[:10].plot(x='State/UnionTerritory',y='Confirmed',kind='bar')

# %%
#graph showing number of cases in Maharashtra state increase with respect to date
mh=covid[covid['State/UnionTerritory']=='Maharashtra'].plot(x='Date',y='Confirmed',figsize = (10,6),fontsize=16)
mh.legend_.remove()

mh.set_title("Maharashtra", fontsize=20)
mh.set_xlabel('Dates', fontsize=20)
mh.set_ylabel('No. of cases', fontsize=20)
# Out:
# Text(0, 0.5, 'No. of cases')

# %%
#graph showing Goa not having new cases in april month
goa=covid[covid['State/UnionTerritory']=='Goa'].plot(x='Date',y='Confirmed',figsize = (10,6),fontsize=16)
goa.legend_.remove()
goa.set_title("Goa", fontsize=20)
goa.set_xlabel('Dates', fontsize=20)
goa.set_ylabel('No. of cases', fontsize=20)
# Out:
# Text(0, 0.5, 'No. of cases')

# %%
#Manipur state work well in fight against corona
manipur=covid[covid['State/UnionTerritory']=='Manipur'].plot(x='Date',y='Confirmed',figsize = (10,6),fontsize=16)
manipur.legend_.remove()
manipur.set_title("Manipur", fontsize=20)
manipur.set_xlabel('Dates', fontsize=20)
manipur.set_ylabel('No. of cases', fontsize=20)
# Out:
# Text(0, 0.5, 'No. of cases')

# %%
labels=['Cured','Death','unknown']
values=[9951,1218,25988]
import matplotlib.pyplot as plt
explode=(0.20,0.20,0)

fig1, ax1 = plt.subplots()
ax1.pie(values, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
no_death=covid_latest[covid_latest['Deaths']==0]
no_death
# Out:
#        Sno      Date     Time         State/UnionTerritory  Cured  Deaths  \
# 1510  1511  02/05/20  5:00 PM  Andaman and Nicobar Islands     16       0
# 1512  1513  02/05/20  5:00 PM            Arunachal Pradesh      1       0
# 1515  1516  02/05/20  5:00 PM                   Chandigarh     17       0
# 1516  1517  02/05/20  5:00 PM                 Chhattisgarh     36       0
# 1518  1519  02/05/20  5:00 PM                          Goa      7       0
# 1526  1527  02/05/20  5:00 PM                       Ladakh     17       0
# 1529  1530  02/05/20  5:00 PM                      Manipur      2       0
# 1531  1532  02/05/20  5:00 PM                      Mizoram      0       0
# 1533  1534  02/05/20  5:00 PM                   Puducherry      5       0
# 1538  1539  02/05/20  5:00 PM                      Tripura      2       0
# 1539  1540  02/05/20  5:00 PM                  Uttarakhand     36       0
#
#       Confirmed
# 1510         33
# 1512          1
# 1515         88
# ...
